# %% [markdown]
# # <img src="files/images/title_graphic.png" />
# ||| WORKING COPY ||| Introducing Decorators

# %% [markdown]
# This document was created on 2014-03-18 at 16:45:21.658906.

# %%
def ff(f, a):
    return f(a)

# %%
ff(len, "12345")
# Out:
# 5

# %%
def add_to(n):
    def adder(x):
        return n+x
    return adder

# %%
add_to(6)
# Out:
# <function __main__.adder>

# %%
fa = add_to(6)

# %%
fa(3)
# Out:
# 9

# %%
def string_required(f):
    def string_checked(arg):
        if type(arg) != str:
            raise ValueError(repr(arg)+" is not a string")
        return f(arg)
    return string_checked

# %%
def must_have_s(arg):
    print(len(arg), arg)

# %%
must_have_s("steve")
# Out:
# 5 steve

# %%
must_have_s([1, 2, 3])
# Out:
# 3 [1, 2, 3]

# %%
must_have_s = string_required(must_have_s)

# %%
must_have_s("steve")
# Out:
# 5 steve

# %%
must_have_s([1, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e73e8057eb5e> in <module>()
# ----> 1 must_have_s([1, 2, 3])
#
# <ipython-input-9-dca475f31a61> in string_checked(arg)
#       2     def string_checked(arg):
#       3         if type(arg) != str:
# ----> 4             raise ValueError(repr(arg)+" is not a string")
#       5         return f(arg)
#       6     return string_checked
#
# ValueError: [1, 2, 3] is not a string

# %%
@string_required
def second(s):
    return 3*s

# %%
second("steve")
# Out:
# 'stevestevesteve'

# %%
second((1, 2, 3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-e3776fad3dee> in <module>()
# ----> 1 second((1, 2, 3))
#
# <ipython-input-9-dca475f31a61> in string_checked(arg)
#       2     def string_checked(arg):
#       3         if type(arg) != str:
# ----> 4             raise ValueError(repr(arg)+" is not a string")
#       5         return f(arg)
#       6     return string_checked
#
# ValueError: (1, 2, 3) is not a string

# %%
@string_required
class little:
    def __init__(self, s):
        self.s = s

# %%
person = little("steve")

# %%
person

# %%
person2 = little([1, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-aad3ca6ec1de> in <module>()
# ----> 1 person2 = little([1, 2, 3])
#
# <ipython-input-9-dca475f31a61> in string_checked(arg)
#       2     def string_checked(arg):
#       3         if type(arg) != str:
# ----> 4             raise ValueError(repr(arg)+" is not a string")
#       5         return f(arg)
#       6     return string_checked
#
# ValueError: [1, 2, 3] is not a string

# %%
person.s
# Out:
# 'steve'

# %%
def barking(cls):
    for name in cls.__dict__:
        if name.startswith("__"):
            continue
        func = getattr(cls, name)
        def woofer(*args, **kw):
            print("Woof")
            return func(*args, **kw)
        setattr(cls, name, woofer)
    return cls

# %%
@barking
class dog_1:
    def shout(self):
        print("hello from dog_1")

# %%
d1 = dog_1()

# %%
d1

# %%
d1.shout()
# Out:
# Woof
# hello from dog_1

# %%
@barking
class dog_3(dog_1):
    def wag(self):
        print("a dog_3 is happy")
    def sniff(self):
        print("a dog 3 is curious")

# %%
d3 = dog_3()

# %%
d3.wag(); d3.sniff(); d3.shout()
# Out:
# Woof
# a dog 3 is curious
# Woof
# a dog 3 is curious
# Woof
# hello from dog_1

# %%
def completely_barking(cls):
    class Null:
        pass
    return Null

# %%
@completely_barking
class something:
    def meth1(self):
        pass
    def meth2(self):
        pass

# %%
something
# Out:
# __main__.Null
